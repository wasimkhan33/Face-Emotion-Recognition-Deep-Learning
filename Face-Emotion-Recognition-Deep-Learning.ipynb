# %% [markdown]
# <a href="https://colab.research.google.com/github/wasimkhan33/Deep-Learning-Capstone-Face-Emotion-Recognition/blob/main/Deep_Learning_Capstone_Face_Emotion_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Source - https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge

# %% [markdown]
# The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centered and occupies about the same amount of space in each image. Each image corresponds to a facial expression in one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral). The dataset contains approximately 36K images

# %% [markdown]
# - Dataset is converted  into raw images and splitted in multiple folders which are train and validation folders.
# - 80% of our images are contained inside the train folder, and the last 20% are inside the validation folder.

# %% [markdown]
# # **Importing Libraries**

# %% [markdown]
# Importing the required python libraries like numpy, seaborn, matplotlib, tensorflow

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from tensorflow.keras.optimizers import SGD
import cv2
import keras
from keras.preprocessing.image import load_img, img_to_array

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Data Visualization**

# %%
# size of the image: So each image will be reduced to a size of 48*48 pixels
pic_size = 48  

# input path for the images
base_path = "/content/drive/MyDrive/Colab Notebooks/Capstone 5/"

plt.figure(0, figsize=(12,20))
cpt = 0

for expression in os.listdir(base_path + "train/"):
    for i in range(1,6):
        cpt = cpt + 1
        plt.subplot(7,5,cpt)
        img = load_img(base_path + "train/" + expression + "/" +os.listdir(base_path + "train/" + expression)[i], target_size=(pic_size, pic_size))
        plt.imshow(img, cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# - However all this diversity of images will contribute to make a more generalizable model.

# %% [markdown]
# The dataset has seven categories of expressions.

# %%
# count number of train images for each expression

for expression in os.listdir(base_path + "train"):
    print(str(len(os.listdir(base_path + "train/" + expression))) + " " + expression + " images")
# Out:
# 7174 happy images
# 4103 fear images
# 4938 sad images
# 3993 angry images
# 436 disgust images
# 4982 neutral images
# 3205 surprise images

# %% [markdown]
# - The image expressions in our training dataset are pretty balanced, except for the 'disgust' category.

# %% [markdown]
# # **Setup the data generators**

# %% [markdown]
# Now we will generate training and testing (validation) batches.

# %%
from keras.preprocessing.image import ImageDataGenerator

# number of images to feed into the NN for every batch
batch_size = 128

datagen_train = ImageDataGenerator()
datagen_validation = ImageDataGenerator()

train_generator = datagen_train.flow_from_directory(base_path + "train",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=True)

validation_generator = datagen_validation.flow_from_directory(base_path + "validation",
                                                    target_size=(pic_size,pic_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
# Out:
# Found 28831 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# - Deep learning models are trained by being fed with batches of data. Keras has a very useful class to automatically feed data from a directory: ImageDataGenerator.

# %% [markdown]
# As of now we have imported libraries, got dataset, and created train and test images. Now its time to move to another important step which is building the CNN Model.

# %% [markdown]
# # **Building the CNN Model.**

# %% [markdown]
# Now let's define the architecture of our CNN:

# %%
# from keras.layers.convolutional import Conv2D

# %%
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.optimizers import RMSprop
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential

# %%
# from keras.optimizers import Adam,SGD,RMSprop

no_of_classes = 7

model = Sequential()

#1st CNN layer
model.add(Conv2D(64,(3,3),padding = 'same',input_shape = (48,48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

#2nd CNN layer
model.add(Conv2D(128,(5,5),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))

#3rd CNN layer
model.add(Conv2D(512,(3,3),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))

#4th CNN layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

#Fully connected 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))


# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(no_of_classes, activation='softmax'))



opt = Adam(lr = 0.0001)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 128)       204928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# activation_1 (Activation)    (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 512)       590336
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 512)       2048
# _________________________________________________________________
# activation_2 (Activation)    (None, 12, 12, 512)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_3 (Activation)    (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# We define our CNN with the following global architecture:
#
# *   4 convolutional layers
# *   2 fully connected layers

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import SVG, Image

# %%
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
Image('model.png',width=400, height=200)

# %% [markdown]
# # **Train the model**

# %% [markdown]
# Now it’s time to train the model and evaluate the results.

# %%
# number of epochs to train the NN
epochs = 50

from keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint("model.h5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(generator=train_generator,
                                steps_per_epoch=train_generator.n//train_generator.batch_size,
                                epochs=epochs,
                                validation_data = validation_generator,
                                validation_steps = validation_generator.n//validation_generator.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# WARNING:tensorflow:From <ipython-input-36-0339d9b236d7>:9: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 225/225 [==============================] - ETA: 0s - loss: 2.0083 - accuracy: 0.2331WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1429s 6s/step - loss: 2.0083 - accuracy: 0.2331 - val_loss: 1.7392 - val_accuracy: 0.2976
# Epoch 2/50
# 225/225 [==============================] - ETA: 0s - loss: 1.8577 - accuracy: 0.2818WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1296s 6s/step - loss: 1.8577 - accuracy: 0.2818 - val_loss: 1.6637 - val_accuracy: 0.3536
# Epoch 3/50
# 225/225 [==============================] - ETA: 0s - loss: 1.7504 - accuracy: 0.3315WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1714s 8s/step - loss: 1.7504 - accuracy: 0.3315 - val_loss: 1.6255 - val_accuracy: 0.3786
# Epoch 4/50
# 225/225 [==============================] - ETA: 0s - loss: 1.6705 - accuracy: 0.3622WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1740s 8s/step - loss: 1.6705 - accuracy: 0.3622 - val_loss: 1.5823 - val_accuracy: 0.3945
# Epoch 5/50
# 225/225 [==============================] - ETA: 0s - loss: 1.6088 - accuracy: 0.3838WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1363s 6s/step - loss: 1.6088 - accuracy: 0.3838 - val_loss: 1.5667 - val_accuracy: 0.4114
# Epoch 6/50
# 225/225 [==============================] - ETA: 0s - loss: 1.5625 - accuracy: 0.3987WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1318s 6s/step - loss: 1.5625 - accuracy: 0.3987 - val_loss: 1.4736 - val_accuracy: 0.4348
# Epoch 7/50
# 225/225 [==============================] - ETA: 0s - loss: 1.5070 - accuracy: 0.4204WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1432s 6s/step - loss: 1.5070 - accuracy: 0.4204 - val_loss: 1.4806 - val_accuracy: 0.4399
# Epoch 8/50
# 225/225 [==============================] - ETA: 0s - loss: 1.4589 - accuracy: 0.4392WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1279s 6s/step - loss: 1.4589 - accuracy: 0.4392 - val_loss: 1.4128 - val_accuracy: 0.4675
# Epoch 9/50
# 225/225 [==============================] - ETA: 0s - loss: 1.4210 - accuracy: 0.4536WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1277s 6s/step - loss: 1.4210 - accuracy: 0.4536 - val_loss: 1.3730 - val_accuracy: 0.4817
# Epoch 10/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3771 - accuracy: 0.4705WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1271s 6s/step - loss: 1.3771 - accuracy: 0.4705 - val_loss: 1.3533 - val_accuracy: 0.4936
# Epoch 11/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3452 - accuracy: 0.4839WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1272s 6s/step - loss: 1.3452 - accuracy: 0.4839 - val_loss: 1.2885 - val_accuracy: 0.5075
# Epoch 12/50
# 225/225 [==============================] - ETA: 0s - loss: 1.3106 - accuracy: 0.4979WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1287s 6s/step - loss: 1.3106 - accuracy: 0.4979 - val_loss: 1.2543 - val_accuracy: 0.5342
# Epoch 13/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2884 - accuracy: 0.5089WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1284s 6s/step - loss: 1.2884 - accuracy: 0.5089 - val_loss: 1.2240 - val_accuracy: 0.5386
# Epoch 14/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2495 - accuracy: 0.5234WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1277s 6s/step - loss: 1.2495 - accuracy: 0.5234 - val_loss: 1.2063 - val_accuracy: 0.5418
# Epoch 15/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2326 - accuracy: 0.5274WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1278s 6s/step - loss: 1.2326 - accuracy: 0.5274 - val_loss: 1.2166 - val_accuracy: 0.5440
# Epoch 16/50
# 225/225 [==============================] - ETA: 0s - loss: 1.2150 - accuracy: 0.5363WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1278s 6s/step - loss: 1.2150 - accuracy: 0.5363 - val_loss: 1.2106 - val_accuracy: 0.5449
# Epoch 17/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1910 - accuracy: 0.5450WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1286s 6s/step - loss: 1.1910 - accuracy: 0.5450 - val_loss: 1.1531 - val_accuracy: 0.5749
# Epoch 18/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1700 - accuracy: 0.5549WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1293s 6s/step - loss: 1.1700 - accuracy: 0.5549 - val_loss: 1.2436 - val_accuracy: 0.5344
# Epoch 19/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1491 - accuracy: 0.5622WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1292s 6s/step - loss: 1.1491 - accuracy: 0.5622 - val_loss: 1.1308 - val_accuracy: 0.5724
# Epoch 20/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1342 - accuracy: 0.5673WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1277s 6s/step - loss: 1.1342 - accuracy: 0.5673 - val_loss: 1.1518 - val_accuracy: 0.5719
# Epoch 21/50
# 225/225 [==============================] - ETA: 0s - loss: 1.1103 - accuracy: 0.5810WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1278s 6s/step - loss: 1.1103 - accuracy: 0.5810 - val_loss: 1.1330 - val_accuracy: 0.5723
# Epoch 22/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0964 - accuracy: 0.5845WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1280s 6s/step - loss: 1.0964 - accuracy: 0.5845 - val_loss: 1.0887 - val_accuracy: 0.5912
# Epoch 23/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0768 - accuracy: 0.5911WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1279s 6s/step - loss: 1.0768 - accuracy: 0.5911 - val_loss: 1.1222 - val_accuracy: 0.5801
# Epoch 24/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0571 - accuracy: 0.6001WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1279s 6s/step - loss: 1.0571 - accuracy: 0.6001 - val_loss: 1.1036 - val_accuracy: 0.5899
# Epoch 25/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0439 - accuracy: 0.6059WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1281s 6s/step - loss: 1.0439 - accuracy: 0.6059 - val_loss: 1.0842 - val_accuracy: 0.5938
# Epoch 26/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0280 - accuracy: 0.6148WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1282s 6s/step - loss: 1.0280 - accuracy: 0.6148 - val_loss: 1.0747 - val_accuracy: 0.6007
# Epoch 27/50
# 225/225 [==============================] - ETA: 0s - loss: 1.0194 - accuracy: 0.6151WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1278s 6s/step - loss: 1.0194 - accuracy: 0.6151 - val_loss: 1.0817 - val_accuracy: 0.6003
# Epoch 28/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9891 - accuracy: 0.6264WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1277s 6s/step - loss: 0.9891 - accuracy: 0.6264 - val_loss: 1.1154 - val_accuracy: 0.5784
# Epoch 29/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9830 - accuracy: 0.6301WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1278s 6s/step - loss: 0.9830 - accuracy: 0.6301 - val_loss: 1.0573 - val_accuracy: 0.6055
# Epoch 30/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9634 - accuracy: 0.6371WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1307s 6s/step - loss: 0.9634 - accuracy: 0.6371 - val_loss: 1.0608 - val_accuracy: 0.6068
# Epoch 31/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9424 - accuracy: 0.6475WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1275s 6s/step - loss: 0.9424 - accuracy: 0.6475 - val_loss: 1.0573 - val_accuracy: 0.6138
# Epoch 32/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9309 - accuracy: 0.6500WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1274s 6s/step - loss: 0.9309 - accuracy: 0.6500 - val_loss: 1.0498 - val_accuracy: 0.6143
# Epoch 33/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9183 - accuracy: 0.6519WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1277s 6s/step - loss: 0.9183 - accuracy: 0.6519 - val_loss: 1.0665 - val_accuracy: 0.6136
# Epoch 34/50
# 225/225 [==============================] - ETA: 0s - loss: 0.9056 - accuracy: 0.6606WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1291s 6s/step - loss: 0.9056 - accuracy: 0.6606 - val_loss: 1.0373 - val_accuracy: 0.6199
# Epoch 35/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8900 - accuracy: 0.6645WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1291s 6s/step - loss: 0.8900 - accuracy: 0.6645 - val_loss: 1.0476 - val_accuracy: 0.6234
# Epoch 36/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8708 - accuracy: 0.6730WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1293s 6s/step - loss: 0.8708 - accuracy: 0.6730 - val_loss: 1.0335 - val_accuracy: 0.6284
# Epoch 37/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8580 - accuracy: 0.6769WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1289s 6s/step - loss: 0.8580 - accuracy: 0.6769 - val_loss: 1.0143 - val_accuracy: 0.6342
# Epoch 38/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8498 - accuracy: 0.6807WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1290s 6s/step - loss: 0.8498 - accuracy: 0.6807 - val_loss: 1.0145 - val_accuracy: 0.6249
# Epoch 39/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8310 - accuracy: 0.6890WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1290s 6s/step - loss: 0.8310 - accuracy: 0.6890 - val_loss: 1.0212 - val_accuracy: 0.6378
# Epoch 40/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8118 - accuracy: 0.6952WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1388s 6s/step - loss: 0.8118 - accuracy: 0.6952 - val_loss: 1.0039 - val_accuracy: 0.6331
# Epoch 41/50
# 225/225 [==============================] - ETA: 0s - loss: 0.8004 - accuracy: 0.7017WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1556s 7s/step - loss: 0.8004 - accuracy: 0.7017 - val_loss: 1.0158 - val_accuracy: 0.6357
# Epoch 42/50
# 225/225 [==============================] - ETA: 0s - loss: 0.7779 - accuracy: 0.7064WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1315s 6s/step - loss: 0.7779 - accuracy: 0.7064 - val_loss: 1.0479 - val_accuracy: 0.6335
# Epoch 43/50
# 225/225 [==============================] - ETA: 0s - loss: 0.7684 - accuracy: 0.7141WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1563s 7s/step - loss: 0.7684 - accuracy: 0.7141 - val_loss: 1.0162 - val_accuracy: 0.6371
# Epoch 44/50
# 225/225 [==============================] - ETA: 0s - loss: 0.7517 - accuracy: 0.7199WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1413s 6s/step - loss: 0.7517 - accuracy: 0.7199 - val_loss: 1.0252 - val_accuracy: 0.6406
# Epoch 45/50
# 225/225 [==============================] - ETA: 0s - loss: 0.7435 - accuracy: 0.7256WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1412s 6s/step - loss: 0.7435 - accuracy: 0.7256 - val_loss: 1.0233 - val_accuracy: 0.6422
# Epoch 46/50
# 225/225 [==============================] - ETA: 0s - loss: 0.7338 - accuracy: 0.7291WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1955s 9s/step - loss: 0.7338 - accuracy: 0.7291 - val_loss: 1.0201 - val_accuracy: 0.6453
# Epoch 47/50
# 225/225 [==============================] - ETA: 0s - loss: 0.7217 - accuracy: 0.7351WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1528s 7s/step - loss: 0.7217 - accuracy: 0.7351 - val_loss: 1.0223 - val_accuracy: 0.6408
# Epoch 48/50
# 225/225 [==============================] - ETA: 0s - loss: 0.7007 - accuracy: 0.7408WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1366s 6s/step - loss: 0.7007 - accuracy: 0.7408 - val_loss: 1.0240 - val_accuracy: 0.6408
# Epoch 49/50
# 225/225 [==============================] - ETA: 0s - loss: 0.6890 - accuracy: 0.7419WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1291s 6s/step - loss: 0.6890 - accuracy: 0.7419 - val_loss: 1.0617 - val_accuracy: 0.6389
# Epoch 50/50
# 225/225 [==============================] - ETA: 0s - loss: 0.6758 - accuracy: 0.7481WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 1282s 6s/step - loss: 0.6758 - accuracy: 0.7481 - val_loss: 1.0557 - val_accuracy: 0.6392

# %% [markdown]
# - It took around 23-24 hours for all epochs.
# - Our best model managed to obtain a  accuracy of approximately 74% on the dataset by running 50 epochs.which is quite good.

# %% [markdown]
# **Saving Model**

# %%
model.save('model1.h5')

# %% [markdown]
# # **Plotting Accuracy & Loss to analyze the results**

# %%
# Plotting Accuracy & Loss

plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# - The training gave the accuracy of 74% and val_accuracy of 63%. It seems good. So, I save the model but the detection i got from live video was average

# %% [markdown]
# Finally we can plot the confusion matrix in order to see how our model classified the images:

# %%
# !pip install -U scikit-learn

# %%
from sklearn.metrics import confusion_matrix
import itertools

# %%
# show the confusion matrix of our predictions

# compute predictions
predictions = model.predict_generator(generator=validation_generator)
y_pred = [np.argmax(probas) for probas in predictions]
y_test = validation_generator.classes
class_names = validation_generator.class_indices.keys()

from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    
# compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, title='Normalized confusion matrix')
plt.show()

# %% [markdown]
# Our model is very good for predicting happy and surprised faces. However it predicts quite poorly feared faces maybe because it confuses them with sad faces.

# %% [markdown]
# # **Real-time predictions**

# %% [markdown]
# First let’s create a class that will give us the predictions of our previously trained model:

# %% [markdown]
# loading the model and weights and making Predictions.

# %%
from tensorflow.keras.models import model_from_json #method to load the model
class FacialExpressionModel(object):
    EMOTIONS_LIST = ["Angry", "Disgust",
                    "Fear", "Happy",
                    "Neutral", "Sad",
                    "Surprise"]
    def __init__(self, model_json_file, model_weights_file):  # init method which takes the model.json file and the model weights file which is in .h5 format
        # load model from JSON file
        with open(model_json_file, "r") as json_file:
            loaded_model_json = json_file.read()
            self.loaded_model = model_from_json(loaded_model_json)
        # load weights into the new model
        self.loaded_model.load_weights(model_weights_file)
        self.loaded_model.make_predict_function()
    def predict_emotion(self, img):
        self.preds = self.loaded_model.predict(img)
        return FacialExpressionModel.EMOTIONS_LIST[np.argmax(self.preds)]

# %% [markdown]
# - In the above code we have first imported model_from_json function which helps us to import the model from a json file

# %% [markdown]
# Implementing a camera class that will do the following operations

# %%
from tensorflow.keras.models import model_from_json
from tensorflow.keras.models import Model

# %% [markdown]
# Also save the model in json format with its weights also saved.

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# Now we will get the frames of the video and will perform the predictions

# %%
import cv2
import numpy as np

# %%
facec = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
model = FacialExpressionModel("model.json", "model1.h5")
font = cv2.FONT_HERSHEY_SIMPLEX

class VideoCamera(object):
    def __init__(self):
        self.video = cv2.VideoCapture(0)
    def __del__(self):
        self.video.release()
    # returns camera frames along with bounding boxes and predictions
    def get_frame(self):
        _, fr = self.video.read()
        gray_fr = cv2.cvtColor(fr, cv2.COLOR_BGR2GRAY)
        faces = facec.detectMultiScale(gray_fr, 1.3, 5)
        for (x, y, w, h) in faces:
            fc = gray_fr[y:y+h, x:x+w]
            roi = cv2.resize(fc, (48, 48))
            pred = model.predict_emotion(roi[np.newaxis, :, :, np.newaxis])
            cv2.putText(fr, pred, (x, y), font, 1, (255, 255, 0), 2)
            cv2.rectangle(fr,(x,y),(x+w,y+h),(255,0,0),2)
        return fr

# %% [markdown]
# - we are importing the OpenCV Module. After this we are setting the CascadeClassifier with Haar Cascade Classifiers that is used to detect features by superimposing predefined patterns over face segments and are used as XML file

# %% [markdown]
# Make the function for calling the above code and showing the output video

# %%
# gen takes camera as parameter.
def gen(camera):  
    while True:
        frame = camera.get_frame()
        cv2.imshow('Facial Expression Recognization',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cv2.destroyAllWindows()

# %% [markdown]
# We have added if condition that if key ‘q’ is presses then loop will be break and the output screen will be destroyed using destroyAllWindows() function.

# %% [markdown]
# Run all the code above by calling the gen function.

# %%
gen(VideoCamera())

# %% [markdown]
# - we have called the gen function and we have passed the VideoCamera class object as the parameter
# - Finally when we run the above line of code the output screen will open showing the live prediction
